# %% [markdown]
# # Raycasting/Lidar simulation

# %% [markdown]
# # Test Ray Environment

# %%
from drone_2d_custom_gym_env.drone_2d_env_raycast import Drone2dEnvRaycastV2
import time  # Import time for delay in example

print("Testing Drone2dEnvRaycastV2...")
env = Drone2dEnvRaycastV2(
    render_sim=True,
    moving_platform=True,
    platform_speed=2.0,
    enable_wind=True,
    initial_pos_random_range_m=10.0,
    enable_raycasting=True,  # Ensure raycasting is on for testing
    num_rays=11,
    ray_fov_deg=120.0,
)
obs = env.reset()

for i in range(1500):
    env.render()
    action = env.action_space.sample()  # Take random actions
    obs, reward, done, info = env.step(action)
    # if i % 50 == 0:
    #     print(f"Step: {i}, Reward: {reward:.3f}")
    # print(f"Observation: {obs}")
    if done:
        print(f"Episode finished after {i+1} steps.")
        env.render()  # Render final frame
        time.sleep(1)
        obs = env.reset()

env.close()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Testing Drone2dEnvRaycastV2...
# RaycastV2 Observation Space Shape: (19,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 120.6 deg. Moving Platform: True
# Step 17: OUT OF BOUNDS!
# Episode finished after 18 steps.
# Pygame closed.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Training the model (Agent)

# %% [markdown]
# ## Training Configuration

# %%
MOVING_PLATFORM = True               #  Train with moving platform
PLATFORM_SPEED = 2.0                 #  Platform speed if moving   
INITIAL_POST_RAMDOM_RANGE_M = 8.0    #  Random start range
MAX_ALLOWED_TILT_ANGLE_RAD = 2       #  Allow slightly more tilt (approx 90 deg)
ENABLE_WIND = True                   #  Train with wind enabled
REWARD_LANDING = 500                 #  reward for landing more high reward increase interest   
REWARD_UN_LANDING = 50

# %%
from stable_baselines3 import PPO

# --- Environment Configuration ---
# These should match the parameters you want to train the agent on
ENV_CONFIG = {
    "render_sim": False,             # IMPORTANT: Keep False for faster training
    "max_steps": 600,                # Max steps per episode during training
    "render_path": False,            # Disable rendering options for speed
    "render_shade": False,
    "shade_distance_m": 2.0,
             
    # No change if we are going resume training training
    
    "moving_platform": MOVING_PLATFORM,        #  Train with moving platform
    "platform_speed": PLATFORM_SPEED,           #  Platform speed if moving
    "initial_pos_random_range_m": INITIAL_POST_RAMDOM_RANGE_M,#  Random start range
    "max_allowed_tilt_angle_rad": MAX_ALLOWED_TILT_ANGLE_RAD, #  Allow slightly more tilt (approx 90 deg)
    "enable_wind": ENABLE_WIND,             #  Train with wind enabled
    'reward_landing': REWARD_LANDING,           #  reward for landing more high reward increase interest   
    'reward_un_landing': REWARD_UN_LANDING          #  reward for unstable landing more high reward increase interest   
    # Note: wind_speed is fixed at 5.0 inside the env for now
}


# --- Training Configuration ---
TOTAL_TIMESTEPS = 3_000_000      # Total steps for training (adjust as needed)
MODEL_ALGORITHM = PPO           # Algorithm to use (PPO is a good default)
POLICY_TYPE = "MlpPolicy"       # Policy type (Multi-Layer Perceptron for vector observations)
LOG_DIR = "logs/drone_ppo_ray/"     # Directory to save TensorBoard logs
MODEL_SAVE_PATH = "models/ppo_ray_drone_1" # Path to save the trained model
CHECKPOINT_FREQ = 50000         # Save a checkpoint every N steps
N_ENVS = 12                      # Number of parallel environments (adjust based on CPU cores)

# %% [markdown]
# ## Training Agent

# %%
import os
import gym

from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import CheckpointCallback

# --- Environment Import ---
# IMPORTANT: Adjust this import path to choose the enviroment

from drone_2d_custom_gym_env.drone_2d_env_raycast import Drone2dEnvRaycastV2


if __name__ == "__main__":
    # --- Setup ---
    os.makedirs(LOG_DIR, exist_ok=True)
    os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)

    print("--- Starting Drone Training ---")
    print(f"Algorithm: {MODEL_ALGORITHM.__name__}")
    print(f"Total Timesteps: {TOTAL_TIMESTEPS}")
    print(f"Environment Config: {ENV_CONFIG}")
    print(f"Using {N_ENVS} parallel environments.")

    # --- Create Vectorized Environment ---
    # Use SubprocVecEnv for true parallelism, DummyVecEnv for debugging
    # `env_kwargs` passes the configuration dictionary to each environment instance
    env = make_vec_env(
        Drone2dEnvRaycastV2,
        n_envs=N_ENVS,
        seed=0,
        vec_env_cls=SubprocVecEnv, # Use SubprocVecEnv for parallel processing
        #vec_env_cls=DummyVecEnv, # Use DummyVecEnv for easier debugging
        env_kwargs=ENV_CONFIG
        )

    # --- Setup Model ---
    # Define the model with policy type, environment, and logging parameters
    # You might need to tune hyperparameters like learning_rate, n_steps, batch_size etc.
    model = MODEL_ALGORITHM(
        POLICY_TYPE,
        env,
        verbose=1, # Print training progress
        tensorboard_log=LOG_DIR,
        # Example of adjusting some hyperparameters (optional):
        # learning_rate=3e-4,
        # n_steps=2048, # Steps per env before update (adjust based on max_steps and N_ENVS)
        # batch_size=64,
        # gamma=0.99, # Discount factor
        # gae_lambda=0.95,
        # ent_coef=0.0, # Entropy coefficient
    )

    # --- Setup Checkpoint Callback ---
    # Saves the model periodically during training
    checkpoint_callback = CheckpointCallback(
        save_freq=max(CHECKPOINT_FREQ // N_ENVS, 1), # Adjust frequency based on N_ENVS
        save_path=LOG_DIR,
        name_prefix="drone_ppo_ckpt"
    )

    # --- Train the Agent ---
    print("\n--- Starting Training ---")
    try:
        model.learn(
            total_timesteps=TOTAL_TIMESTEPS,
            log_interval=10, # Log metrics every 10 updates
            tb_log_name=f"{MODEL_ALGORITHM.__name__}_Drone", # Name for TensorBoard run
            callback=checkpoint_callback # Add the checkpoint callback
            )
    except Exception as e:
        print(f"\n!!! Error during training: {e} !!!")
        print("Attempting to save model before exiting...")
        model.save(f"{MODEL_SAVE_PATH}_error")
    finally:
        # --- Save the Final Model ---
        print("\n--- Training Finished (or interrupted) ---")
        print(f"Saving final model to: {MODEL_SAVE_PATH}")
        model.save(MODEL_SAVE_PATH)

        # --- Clean up ---
        env.close() # Close the vectorized environment
        print("Environment closed.")

    print("\n--- Training Script Complete ---")
    print(f"To monitor training, run: tensorboard --logdir {LOG_DIR}")

# --- END OF FILE train_drone_agent.py ---
# Out:
# --- Starting Drone Training ---
# Algorithm: PPO
# Total Timesteps: 3000000
# Environment Config: {'render_sim': False, 'max_steps': 750, 'render_path': False, 'render_shade': False, 'shade_distance_m': 2.0, 'moving_platform': True, 'platform_speed': 2.0, 'initial_pos_random_range_m': 8.0, 'max_allowed_tilt_angle_rad': 2, 'enable_wind': True, 'reward_landing': 500, 'reward_un_landing': 50}
# Using 12 parallel environments.
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 295.3 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 138.8 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 313.9 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 185.3 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 215.8 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 170.7 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 250.9 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 316.9 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 337.1 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 181.8 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 274.2 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 273.4 deg. Moving Platform: True
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
#
# --- Starting Training ---
# Logging to logs/drone_ppo_ray/PPO_Drone_1
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Step 45: OUT OF BOUNDS!
# Step 55: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 61: LOST CONTROL!
# Step 74: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 85: OUT OF BOUNDS!
# Step 101: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 129: LOST CONTROL!
# Step 84: OUT OF BOUNDS!
# Step 99: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 101: OUT OF BOUNDS!
# Step 81: OUT OF BOUNDS!
# Step 65: OUT OF BOUNDS!
# Step 93: LOST CONTROL!
# Step 57: OUT OF BOUNDS!
# Step 82: LOST CONTROL!
# Step 68: LOST CONTROL!
# Step 107: LOST CONTROL!
# Step 124: LOST CONTROL!
# Step 45: OUT OF BOUNDS!
# Step 104: LOST CONTROL!
# Step 100: LOST CONTROL!
# Step 59: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
# Step 99: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 97: OUT OF BOUNDS!
# Step 65: OUT OF BOUNDS!
# Step 76: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 101: OUT OF BOUNDS!
# Step 70: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 103: OUT OF BOUNDS!
# Step 110: LOST CONTROL!
# Step 65: LOST CONTROL!
# Step 128: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 76: OUT OF BOUNDS!
# Step 63: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 135: LOST CONTROL!
# Step 122: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 46: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 95: OUT OF BOUNDS!
# Step 75: LOST CONTROL!
# Step 101: OUT OF BOUNDS!
# Step 78: OUT OF BOUNDS!
# Step 52: LOST CONTROL!
# Step 68: OUT OF BOUNDS!
# Step 66: OUT OF BOUNDS!
# Step 77: OUT OF BOUNDS!
# Step 93: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 132: LOST CONTROL!
# Step 56: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 104: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 108: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 94: OUT OF BOUNDS!
# Step 100: OUT OF BOUNDS!
# Step 100: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 72: LOST CONTROL!
# Step 53: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 64: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 69: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 84: OUT OF BOUNDS!
# Step 86: OUT OF BOUNDS!
# Step 81: OUT OF BOUNDS!
# Step 104: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 108: OUT OF BOUNDS!
# Step 87: LOST CONTROL!
# Step 109: LOST CONTROL!
# Step 93: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 200.6 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 198.4 deg. Moving Platform: True
# Step 141: LOST CONTROL!
# Step 113: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 238.5 deg. Moving Platform: True
# Step 55: LOST CONTROL!
# Step 91: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 98.0 deg. Moving Platform: True
# Step 115: OUT OF BOUNDS!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 259.5 deg. Moving Platform: True
# Step 88: OUT OF BOUNDS!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 290.7 deg. Moving Platform: True
# Step 159: LOST CONTROL!
# Step 71: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 163.2 deg. Moving Platform: True
# Step 98: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 149.5 deg. Moving Platform: True
# Step 78: OUT OF BOUNDS!
# Step 66: OUT OF BOUNDS!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 92.9 deg. Moving Platform: True
# Step 95: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 219.5 deg. Moving Platform: True
# Step 65: OUT OF BOUNDS!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 120.9 deg. Moving Platform: True
# Step 114: OUT OF BOUNDS!
# Step 44: OUT OF BOUNDS!
# Step 47: OUT OF BOUNDS!
# Step 113: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 87: OUT OF BOUNDS!
# Step 74: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 107: LOST CONTROL!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 175.9 deg. Moving Platform: True
# Step 72: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 83: OUT OF BOUNDS!
# Step 92: LOST CONTROL!
# Step 140: LOST CONTROL!
# Step 58: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 112: OUT OF BOUNDS!
# Step 72: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 50: LOST CONTROL!
# Step 54: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 90: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 54: OUT OF BOUNDS!
# Step 65: LOST CONTROL!
# Step 55: LOST CONTROL!
# Step 101: OUT OF BOUNDS!
# Step 112: OUT OF BOUNDS!
# Step 74: LOST CONTROL!
# Step 144: LOST CONTROL!
# Step 114: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 58: OUT OF BOUNDS!
# Step 80: OUT OF BOUNDS!
# Step 71: OUT OF BOUNDS!
# Step 55: LOST CONTROL!
# Step 120: LOST CONTROL!
# Step 125: LOST CONTROL!
# Step 39: OUT OF BOUNDS!
# Step 134: LOST CONTROL!
# Step 64: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 65: LOST CONTROL!
# Step 58: LOST CONTROL!
# Step 103: OUT OF BOUNDS!
# Step 87: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 74: OUT OF BOUNDS!
# Step 103: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 51: OUT OF BOUNDS!
# Step 75: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 66: OUT OF BOUNDS!
# Step 66: OUT OF BOUNDS!
# Step 163: LOST CONTROL!
# Step 89: OUT OF BOUNDS!
# Step 81: OUT OF BOUNDS!
# Step 49: LOST CONTROL!
# Step 40: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 94: OUT OF BOUNDS!
# Step 89: OUT OF BOUNDS!
# Step 83: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 120: LOST CONTROL!
# Step 56: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 80: LOST CONTROL!
# Step 100: LOST CONTROL!
# Step 105: OUT OF BOUNDS!
# Step 65: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 90: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 107: LOST CONTROL!
# Step 105: OUT OF BOUNDS!
# Step 164: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 73: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 30.3 deg. Moving Platform: True
# Step 136: LOST CONTROL!
# Step 134: LOST CONTROL!
# Step 100: LOST CONTROL!Step 73: OUT OF BOUNDS!
#
# Step 116: LOST CONTROL!
# Step 97: OUT OF BOUNDS!
# Step 103: OUT OF BOUNDS!
# Step 58: LOST CONTROL!
# Step 87: OUT OF BOUNDS!
# Step 82: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 265.5 deg. Moving Platform: True
# Step 90: LOST CONTROL!
# Step 115: LOST CONTROL!
# Step 84: OUT OF BOUNDS!
# Step 64: OUT OF BOUNDS!
# Step 100: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 253.1 deg. Moving Platform: True
# Step 89: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 218.7 deg. Moving Platform: True
# Step 114: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 82: OUT OF BOUNDS!
# Step 124: OUT OF BOUNDS!
# Step 79: LOST CONTROL!
# Step 97: LOST CONTROL!Step 48: LOST CONTROL!
#
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 348.2 deg. Moving Platform: True
# Step 70: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 242.4 deg. Moving Platform: True
# Step 113: LOST CONTROL!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 291.5 deg. Moving Platform: True
# Step 87: LOST CONTROL!
# Step 66: LOST CONTROL!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 113.9 deg. Moving Platform: True
# Step 70: OUT OF BOUNDS!
# Step 120: LOST CONTROL!
# Step 94: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 342.0 deg. Moving Platform: True
# Step 90: OUT OF BOUNDS!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 227.1 deg. Moving Platform: True
# Step 95: LOST CONTROL!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 230.4 deg. Moving Platform: True
# Step 71: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 128: LOST CONTROL!
# Step 159: LOST CONTROL!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 209.9 deg. Moving Platform: True
# Step 70: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 67: OUT OF BOUNDS!
# Step 80: LOST CONTROL!
# Step 86: LOST CONTROL!
# Step 71: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 63: LOST CONTROL!
# Step 167: OUT OF BOUNDS!
# Step 63: OUT OF BOUNDS!
# Step 63: OUT OF BOUNDS!
# Step 98: OUT OF BOUNDS!
# Step 85: LOST CONTROL!
# Step 99: OUT OF BOUNDS!
# Step 114: LOST CONTROL!
# Step 66: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 66: LOST CONTROL!
# Step 80: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 80: OUT OF BOUNDS!
# Step 97: OUT OF BOUNDS!
# Step 40: OUT OF BOUNDS!
# Step 89: OUT OF BOUNDS!
# Step 52: OUT OF BOUNDS!
# Step 81: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 49: OUT OF BOUNDS!
# Step 67: OUT OF BOUNDS!
# Step 79: LOST CONTROL!
# Step 100: LOST CONTROL!
# Step 112: OUT OF BOUNDS!
# Step 115: LOST CONTROL!
# Step 53: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 86: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 130: LOST CONTROL!
# Step 67: OUT OF BOUNDS!
# Step 66: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 76: OUT OF BOUNDS!
# Step 140: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 75: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 75: OUT OF BOUNDS!
# Step 82: OUT OF BOUNDS!
# Step 91: LOST CONTROL!
# Step 68: OUT OF BOUNDS!
# Step 86: OUT OF BOUNDS!
# Step 74: OUT OF BOUNDS!
# Step 107: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 122: OUT OF BOUNDS!
# Step 69: OUT OF BOUNDS!
# Step 70: OUT OF BOUNDS!
# Step 64: LOST CONTROL!
# Step 74: OUT OF BOUNDS!
# Step 73: LOST CONTROL!
# Step 103: OUT OF BOUNDS!
# Step 49: OUT OF BOUNDS!
# Step 103: LOST CONTROL!
# Step 108: LOST CONTROL!
# Step 119: LOST CONTROL!
# Step 57: OUT OF BOUNDS!
# Step 95: OUT OF BOUNDS!
# Step 40: OUT OF BOUNDS!
# Step 104: OUT OF BOUNDS!
# Step 62: LOST CONTROL!
# Step 75: OUT OF BOUNDS!
# Step 103: LOST CONTROL!
# Step 52: OUT OF BOUNDS!
# Step 98: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 145: OUT OF BOUNDS!
# Step 97: LOST CONTROL!
# Step 63: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 65: LOST CONTROL!
# Step 56: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 59: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 164.4 deg. Moving Platform: True
# Step 87: LOST CONTROL!
# Step 121: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 23.1 deg. Moving Platform: True
# Step 114: OUT OF BOUNDS!
# Step 78: OUT OF BOUNDS!
# Step 116: OUT OF BOUNDS!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 97.1 deg. Moving Platform: True
# Step 67: OUT OF BOUNDS!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 257.0 deg. Moving Platform: True
# Step 110: OUT OF BOUNDS!
# Step 51: OUT OF BOUNDS!
# Step 78: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 323.2 deg. Moving Platform: True
# Step 55: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 293.5 deg. Moving Platform: True
# Step 64: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 122.1 deg. Moving Platform: True
# Step 66: LOST CONTROL!
# Step 108: LOST CONTROL!
# Step 68: LOST CONTROL!
# Step 102: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 174.9 deg. Moving Platform: True
# Step 43: OUT OF BOUNDS!
# Step 34: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 71: OUT OF BOUNDS!
# Step 93: LOST CONTROL!
# Step 111: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 104.9 deg. Moving Platform: True
# Step 105: LOST CONTROL!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 313.7 deg. Moving Platform: True
# Step 181: OUT OF BOUNDS!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 120.0 deg. Moving Platform: True
# Step 47: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
# Step 102: OUT OF BOUNDS!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 172.9 deg. Moving Platform: True
# Step 84: OUT OF BOUNDS!
# Step 92: OUT OF BOUNDS!
# Step 101: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
# Step 155: OUT OF BOUNDS!
# Step 85: OUT OF BOUNDS!
# Step 78: LOST CONTROL!
# Step 96: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 81: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 46: OUT OF BOUNDS!
# Step 78: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 165: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 67: LOST CONTROL!
# Step 47: OUT OF BOUNDS!
# Step 125: LOST CONTROL!
# Step 87: OUT OF BOUNDS!
# Step 69: LOST CONTROL!
# Step 155: OUT OF BOUNDS!
# Step 82: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 81: OUT OF BOUNDS!
# Step 82: OUT OF BOUNDS!
# Step 82: LOST CONTROL!
# Step 126: OUT OF BOUNDS!
# Step 68: OUT OF BOUNDS!
# Step 76: LOST CONTROL!
# Step 104: OUT OF BOUNDS!
# Step 64: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 76: LOST CONTROL!
# Step 116: OUT OF BOUNDS!
# Step 78: OUT OF BOUNDS!
# Step 110: OUT OF BOUNDS!
# Step 51: LOST CONTROL!
# Step 56: LOST CONTROL!
# Step 58: LOST CONTROL!
# Step 129: LOST CONTROL!
# Step 65: LOST CONTROL!
# Step 80: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 67: LOST CONTROL!
# Step 75: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 76: OUT OF BOUNDS!
# Step 60: OUT OF BOUNDS!
# Step 136: OUT OF BOUNDS!
# Step 60: LOST CONTROL!
# Step 66: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 74: LOST CONTROL!
# Step 87: LOST CONTROL!
# Step 82: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 178: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
# Step 104: LOST CONTROL!
# Step 131: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 112: LOST CONTROL!
# Step 104: LOST CONTROL!
# Step 70: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 323.2 deg. Moving Platform: True
# Step 99: LOST CONTROL!
# Step 104: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 298.5 deg. Moving Platform: True
# Step 113: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 100: OUT OF BOUNDS!
# Step 74: OUT OF BOUNDS!
# Step 103: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 74: LOST CONTROL!
# Step 53: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 89: OUT OF BOUNDS!
# Step 47: OUT OF BOUNDS!
# Step 76: OUT OF BOUNDS!
# Step 58: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 203.9 deg. Moving Platform: True
# Step 89: OUT OF BOUNDS!
# Step 116: OUT OF BOUNDS!
# Step 65: OUT OF BOUNDS!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 76.2 deg. Moving Platform: True
# Step 85: LOST CONTROL!
# Step 128: LOST CONTROL!
# Step 121: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 290.7 deg. Moving Platform: True
# Step 85: LOST CONTROL!
# Step 74: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 116: OUT OF BOUNDS!
# Step 88: OUT OF BOUNDS!
# Step 90: OUT OF BOUNDS!
# Step 62: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 93: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 101.3 deg. Moving Platform: True
# Step 128: OUT OF BOUNDS!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 15.1 deg. Moving Platform: True
# Step 95: OUT OF BOUNDS!
# Step 98: LOST CONTROL!
# Step 78: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 118.5 deg. Moving Platform: True
# Step 58: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 73.3 deg. Moving Platform: True
# Step 86: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 71: OUT OF BOUNDS!
# Step 113: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 142.8 deg. Moving Platform: True
# Step 102: LOST CONTROL!
# Step 113: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 89.7 deg. Moving Platform: True
# Step 111: OUT OF BOUNDS!
# Step 79: LOST CONTROL!
# Step 84: LOST CONTROL!
# Step 88: LOST CONTROL!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 1.5 deg. Moving Platform: True
# Step 83: OUT OF BOUNDS!
# Step 64: LOST CONTROL!
# Step 70: LOST CONTROL!
# Step 125: OUT OF BOUNDS!
# Step 69: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 68: LOST CONTROL!
# Step 93: OUT OF BOUNDS!
# Step 51: OUT OF BOUNDS!
# Step 60: LOST CONTROL!
# Step 69: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 92: OUT OF BOUNDS!
# Step 69: LOST CONTROL!
# Step 132: LOST CONTROL!
# Step 47: LOST CONTROL!
# Step 82: LOST CONTROL!
# Step 89: OUT OF BOUNDS!
# Step 93: OUT OF BOUNDS!
# Step 113: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 138: LOST CONTROL!
# Step 69: OUT OF BOUNDS!
# Step 68: OUT OF BOUNDS!
# Step 66: LOST CONTROL!
# Step 65: OUT OF BOUNDS!
# Step 107: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 47: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 54: LOST CONTROL!
# Step 124: LOST CONTROL!
# Step 101: LOST CONTROL!
# Step 64: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 96: LOST CONTROL!
# Step 114: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 101: LOST CONTROL!
# Step 135: LOST CONTROL!
# Step 68: LOST CONTROL!
# Step 54: LOST CONTROL!
# Step 151: OUT OF BOUNDS!
# Step 58: OUT OF BOUNDS!
# Step 79: LOST CONTROL!
# Step 130: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 66: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 33.3 deg. Moving Platform: True
# Step 100: OUT OF BOUNDS!
# Step 65: LOST CONTROL!
# Step 69: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 65: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 82: OUT OF BOUNDS!
# Step 75: LOST CONTROL!
# Step 56: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 290.9 deg. Moving Platform: True
# Step 88: LOST CONTROL!
# Step 96: OUT OF BOUNDS!
# Step 58: LOST CONTROL!
# Step 53: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
# Step 108: OUT OF BOUNDS!
# Step 76: LOST CONTROL!
# Step 114: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 101: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 84: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 65: OUT OF BOUNDS!
# Step 98: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 59: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 62: OUT OF BOUNDS!
# Step 90: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 73: LOST CONTROL!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 248.2 deg. Moving Platform: True
# Step 111: OUT OF BOUNDS!
# Step 98: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 149.4 deg. Moving Platform: True
# Step 74: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 4.8 deg. Moving Platform: True
# Step 106: LOST CONTROL!
# Step 106: OUT OF BOUNDS!
# Step 110: LOST CONTROL!
# Step 86: LOST CONTROL!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 359.3 deg. Moving Platform: True
# Step 114: OUT OF BOUNDS!
# Step 93: LOST CONTROL!
# Step 99: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 113: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 73: LOST CONTROL!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 27.0 deg. Moving Platform: True
# Step 39: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 192.5 deg. Moving Platform: True
# Step 70: LOST CONTROL!
# Step 45: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 271.3 deg. Moving Platform: True
# Step 65: LOST CONTROL!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 243.8 deg. Moving Platform: True
# Step 119: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 109: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 136.0 deg. Moving Platform: True
# Step 81: OUT OF BOUNDS!
# Step 98: OUT OF BOUNDS!
# Step 99: OUT OF BOUNDS!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 327.5 deg. Moving Platform: True
# Step 118: OUT OF BOUNDS!
# Step 55: LOST CONTROL!
# Step 49: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 57: OUT OF BOUNDS!
# Step 81: OUT OF BOUNDS!
# Step 122: LOST CONTROL!
# Step 99: LOST CONTROL!
# Step 147: LOST CONTROL!
# Step 102: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 75: LOST CONTROL!
# Step 105: LOST CONTROL!
# Step 64: OUT OF BOUNDS!
# Step 97: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 47: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 120: LOST CONTROL!
# Step 131: LOST CONTROL!
# Step 52: LOST CONTROL!
# Step 136: LOST CONTROL!
# Step 81: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 64: LOST CONTROL!
# Step 67: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 85: OUT OF BOUNDS!
# Step 56: OUT OF BOUNDS!
# Step 104: LOST CONTROL!
# Step 59: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 55: OUT OF BOUNDS!
# Step 75: OUT OF BOUNDS!
# Step 102: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 145: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 71: OUT OF BOUNDS!
# Step 114: OUT OF BOUNDS!
# Step 92: LOST CONTROL!
# Step 57: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 42: OUT OF BOUNDS!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 16.8 deg. Moving Platform: True
# Step 134: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
# Step 122: LOST CONTROL!
# Step 56: LOST CONTROL!
# Step 120: OUT OF BOUNDS!
# Step 73: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 100: LOST CONTROL!
# Step 52: LOST CONTROL!
# Step 124: LOST CONTROL!
# Step 49: OUT OF BOUNDS!
# Step 63: LOST CONTROL!
# Step 67: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 92: LOST CONTROL!
# Step 70: OUT OF BOUNDS!
# Step 76: OUT OF BOUNDS!
# Step 64: LOST CONTROL!
# Step 113: LOST CONTROL!
# Step 105: OUT OF BOUNDS!
# Step 124: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 350.4 deg. Moving Platform: True
# Step 80: OUT OF BOUNDS!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 158.4 deg. Moving Platform: True
# Step 75: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 82: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 105: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 83: OUT OF BOUNDS!
# Step 126: OUT OF BOUNDS!
# Step 66: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 55: OUT OF BOUNDS!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 283.3 deg. Moving Platform: True
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 232.8 deg. Moving Platform: True
# Step 76: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 55: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 100: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 61.4 deg. Moving Platform: True
# Step 42: OUT OF BOUNDS!
# Step 101: OUT OF BOUNDS!
# Step 59: OUT OF BOUNDS!
# Step 53: LOST CONTROL!
# Step 86: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 270.4 deg. Moving Platform: True
# Step 116: LOST CONTROL!
# Step 61: OUT OF BOUNDS!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 200.1 deg. Moving Platform: True
# Step 78: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 104: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 58.0 deg. Moving Platform: True
# Step 91: LOST CONTROL!
# Step 144: LOST CONTROL!
# Step 99: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 119.7 deg. Moving Platform: True
# Step 105: OUT OF BOUNDS!
# Step 75: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
# Step 74: LOST CONTROL!
# Step 52: OUT OF BOUNDS!
# Step 103: OUT OF BOUNDS!
# Step 116: LOST CONTROL!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 96.5 deg. Moving Platform: True
# Step 97: OUT OF BOUNDS!
# Step 51: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 32.2 deg. Moving Platform: True
# Step 79: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 44: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
# Step 68: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 103: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 92: LOST CONTROL!
# Step 65: OUT OF BOUNDS!
# Step 59: OUT OF BOUNDS!
# Step 69: LOST CONTROL!
# Step 60: OUT OF BOUNDS!
# Step 56: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
# Step 139: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 96: OUT OF BOUNDS!
# Step 106: LOST CONTROL!
# Step 74: OUT OF BOUNDS!
# Step 54: LOST CONTROL!
# Step 101: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 108: OUT OF BOUNDS!
# Step 58: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 66: LOST CONTROL!
# Step 106: OUT OF BOUNDS!
# Step 103: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 95: OUT OF BOUNDS!
# Step 97: LOST CONTROL!
# Step 114: OUT OF BOUNDS!
# Step 84: OUT OF BOUNDS!
# Step 116: OUT OF BOUNDS!
# Step 41: OUT OF BOUNDS!
# Step 109: OUT OF BOUNDS!
# Step 106: LOST CONTROL!
# Step 75: OUT OF BOUNDS!
# Step 112: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 205.8 deg. Moving Platform: True
# Step 82: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 87: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 62: OUT OF BOUNDS!
# Step 75: LOST CONTROL!
# Step 77: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 86: OUT OF BOUNDS!
# Step 66: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 161.0 deg. Moving Platform: True
# Step 114: OUT OF BOUNDS!
# Step 42: OUT OF BOUNDS!
# Step 68: OUT OF BOUNDS!
# Step 62: LOST CONTROL!
# Step 80: LOST CONTROL!
# Step 119: LOST CONTROL!
# Step 132: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 60: OUT OF BOUNDS!
# Step 110: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 96: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 302.0 deg. Moving Platform: True
# Step 77: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 83.0 deg. Moving Platform: True
# Step 85: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
# Step 55: LOST CONTROL!
# Step 76: LOST CONTROL!
# Step 76: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 76: OUT OF BOUNDS!
# Step 117: LOST CONTROL!
# Step 108: OUT OF BOUNDS!
# Step 91: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 25.7 deg. Moving Platform: True
# Step 47: LOST CONTROL!
# Step 109: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 87: OUT OF BOUNDS!
# Step 84: LOST CONTROL!
# Step 166: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 100: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 250.6 deg. Moving Platform: True
# Step 102: LOST CONTROL!
# Step 41: OUT OF BOUNDS!
# Step 135: OUT OF BOUNDS!
# Step 116: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
# Step 77: OUT OF BOUNDS!
# Step 99: LOST CONTROL!
# Step 97: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 230.5 deg. Moving Platform: True
# Step 69: OUT OF BOUNDS!
# Step 116: OUT OF BOUNDS!
# Step 63: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 219.3 deg. Moving Platform: True
# Step 86: OUT OF BOUNDS!
# Step 90: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 109: LOST CONTROL!
# Step 120: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 83.7 deg. Moving Platform: True
# Step 89: LOST CONTROL!
# Step 73: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 298.6 deg. Moving Platform: True
# Step 85: LOST CONTROL!
# Step 118: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 100: LOST CONTROL!
# Step 61: LOST CONTROL!
# Step 58: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 115: OUT OF BOUNDS!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 65.2 deg. Moving Platform: True
# Step 105: LOST CONTROL!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 40.3 deg. Moving Platform: True
# Step 88: OUT OF BOUNDS!
# Step 105: LOST CONTROL!
# Step 112: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 81: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 82: LOST CONTROL!
# Step 87: LOST CONTROL!
# Step 92: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 120: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
# Step 68: OUT OF BOUNDS!
# Step 88: OUT OF BOUNDS!
# Step 98: LOST CONTROL!
# Step 112: LOST CONTROL!
# Step 75: LOST CONTROL!
# Step 71: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 72: OUT OF BOUNDS!
# Step 97: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 58: OUT OF BOUNDS!
# Step 99: LOST CONTROL!
# Step 86: LOST CONTROL!
# Step 59: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 114: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 62: OUT OF BOUNDS!
# Step 87: OUT OF BOUNDS!
# Step 58: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 330.4 deg. Moving Platform: True
# Step 80: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 99: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 105: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 93: OUT OF BOUNDS!
# Step 105: LOST CONTROL!
# Step 58: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 234.8 deg. Moving Platform: True
# Step 64: OUT OF BOUNDS!
# Step 64: LOST CONTROL!
# Step 58: OUT OF BOUNDS!
# Step 76: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 98: LOST CONTROL!Step 79: OUT OF BOUNDS!
#
# Step 87: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 59: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 75: OUT OF BOUNDS!
# Step 51: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 67: LOST CONTROL!
# Step 49: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 46: OUT OF BOUNDS!
# Step 106: LOST CONTROL!
# Step 59: OUT OF BOUNDS!
# Step 99: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 165.9 deg. Moving Platform: True
# Step 97: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 66.3 deg. Moving Platform: True
# Step 83: OUT OF BOUNDS!
# Step 88: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 85: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 86: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 67: OUT OF BOUNDS!
# Step 72: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 63: OUT OF BOUNDS!
# Step 52: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 79.5 deg. Moving Platform: True
# Step 93: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 52.0 deg. Moving Platform: True
# Step 65: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 132.9 deg. Moving Platform: True
# Step 85: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 70: OUT OF BOUNDS!
# Step 82: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 134: LOST CONTROL!
# Step 89: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 173.0 deg. Moving Platform: True
# Step 104: LOST CONTROL!
# Step 76: LOST CONTROL!
# Step 112: OUT OF BOUNDS!
# Step 86: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 82: OUT OF BOUNDS!
# Step 90: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 298.5 deg. Moving Platform: True
# Step 168: LOST CONTROL!
# Step 54: LOST CONTROL!
# Step 79: OUT OF BOUNDS!
# Step 104: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 292.3 deg. Moving Platform: True
# Step 99: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 56: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 89.1 deg. Moving Platform: True
# Step 125: LOST CONTROL!
# Step 58: LOST CONTROL!
# Step 103: LOST CONTROL!
# Step 48: OUT OF BOUNDS!
# Step 114: LOST CONTROL!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 85.8 deg. Moving Platform: True
# Step 76: LOST CONTROL!
# Step 80: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 68: OUT OF BOUNDS!
# Step 138: OUT OF BOUNDS!
# Step 87: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 58: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 103: LOST CONTROL!
# Step 74: OUT OF BOUNDS!
# Step 156: LOST CONTROL!
# Step 49: OUT OF BOUNDS!
# Step 49: OUT OF BOUNDS!
# Step 123: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 109: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 60: LOST CONTROL!
# Step 97: LOST CONTROL!
# Step 84: OUT OF BOUNDS!
# Step 94: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 80: LOST CONTROL!
# Step 114: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 100: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 57: OUT OF BOUNDS!
# Step 112: LOST CONTROL!
# Step 126: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 92: OUT OF BOUNDS!
# Step 104: OUT OF BOUNDS!
# Step 87: OUT OF BOUNDS!
# Step 78: LOST CONTROL!
# Step 96: LOST CONTROL!
# Step 61: LOST CONTROL!
# Step 96: LOST CONTROL!
# Step 125: LOST CONTROL!
# Step 74: OUT OF BOUNDS!
# Step 70: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 264.6 deg. Moving Platform: True
# Step 105: OUT OF BOUNDS!
# Step 139: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 96: OUT OF BOUNDS!
# Step 57: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 95: OUT OF BOUNDS!
# Step 123: LOST CONTROL!
# Step 140: LOST CONTROL!
# Step 70: OUT OF BOUNDS!
# Step 109: LOST CONTROL!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 318.0 deg. Moving Platform: True
# Step 58: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 64: LOST CONTROL!
# Step 63: OUT OF BOUNDS!
# Step 63: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 91: OUT OF BOUNDS!Step 105: LOST CONTROL!
#
# Step 68: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 118: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 79: LOST CONTROL!
# Step 39: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 310.5 deg. Moving Platform: True
# Step 90: LOST CONTROL!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 217.9 deg. Moving Platform: True
# Step 139: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
# Step 72: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 52: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 202.3 deg. Moving Platform: True
# Step 133: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 90: OUT OF BOUNDS!
# Step 94: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 63: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 133.9 deg. Moving Platform: True
# Step 112: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 158.5 deg. Moving Platform: True
# Step 76: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 72: LOST CONTROL!
# Step 61: LOST CONTROL!
# Step 44: OUT OF BOUNDS!
# Step 96: OUT OF BOUNDS!
# Step 81: LOST CONTROL!
# Step 68: LOST CONTROL!
# Step 83: OUT OF BOUNDS!
# Step 61: OUT OF BOUNDS!
# Step 99: LOST CONTROL!
# Step 45: OUT OF BOUNDS!
# Step 89: LOST CONTROL!
# Step 67: OUT OF BOUNDS!
# Step 54: OUT OF BOUNDS!
# Step 72: LOST CONTROL!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 127.5 deg. Moving Platform: True
# Step 101: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 102: OUT OF BOUNDS!
# Step 96: LOST CONTROL!
# Step 73: OUT OF BOUNDS!
# Step 48: OUT OF BOUNDS!
# Step 55: OUT OF BOUNDS!
# Step 77: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 56.8 deg. Moving Platform: True
# Step 122: LOST CONTROL!
# Step 106: LOST CONTROL!
# Step 59: OUT OF BOUNDS!
# Step 63: LOST CONTROL!
# Step 66: OUT OF BOUNDS!
# Step 97: LOST CONTROL!
# Step 85: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 104.0 deg. Moving Platform: True
# Step 69: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 137: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 13.3 deg. Moving Platform: True
# Step 63: OUT OF BOUNDS!
# Step 110: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 99: LOST CONTROL!
# Step 72: OUT OF BOUNDS!
# Step 107: OUT OF BOUNDS!
# Step 92: LOST CONTROL!
# Step 76: LOST CONTROL!
# Step 126: OUT OF BOUNDS!
# Step 79: LOST CONTROL!
# Step 131: LOST CONTROL!
# Step 115: OUT OF BOUNDS!
# Step 101: LOST CONTROL!
# Step 44: OUT OF BOUNDS!
# Step 137: LOST CONTROL!
# Step 104: OUT OF BOUNDS!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 311.4 deg. Moving Platform: True
# Step 81: LOST CONTROL!
# Step 66: LOST CONTROL!
# Step 111: LOST CONTROL!
# Step 87: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 214.2 deg. Moving Platform: True
# Step 55: LOST CONTROL!
# Step 139: LOST CONTROL!
# Step 96: OUT OF BOUNDS!
# Step 121: LOST CONTROL!
# Step 100: LOST CONTROL!
# Step 64: LOST CONTROL!
# Step 85: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 104: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 98: OUT OF BOUNDS!
# Step 62: LOST CONTROL!
# Step 111: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 87: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 73: LOST CONTROL!
# Step 102: OUT OF BOUNDS!
# Step 90: LOST CONTROL!
# Step 92: LOST CONTROL!
# Step 69: OUT OF BOUNDS!
# Step 74: OUT OF BOUNDS!
# Step 168: OUT OF BOUNDS!
# Step 138: LOST CONTROL!
# Step 116: LOST CONTROL!
# Step 62: LOST CONTROL!
# Step 57: LOST CONTROL!
# Step 76: LOST CONTROL!
# Step 116: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
# Step 86: LOST CONTROL!
# Step 121: LOST CONTROL!
# Step 63: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 178: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 71.1 deg. Moving Platform: True
# Step 123: LOST CONTROL!
# Step 90: LOST CONTROL!
# Step 94: OUT OF BOUNDS!
# Step 134: OUT OF BOUNDS!
# Step 165: LOST CONTROL!
# Step 112: OUT OF BOUNDS!
# Step 137: LOST CONTROL!
# Step 95: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 175.9 deg. Moving Platform: True
# Step 129: OUT OF BOUNDS!
# Step 86: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 246.3 deg. Moving Platform: True
# Step 82: OUT OF BOUNDS!
# Step 112: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 110.9 deg. Moving Platform: True
# Step 99: LOST CONTROL!
# Step 87: OUT OF BOUNDS!
# Step 85: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 51.3 deg. Moving Platform: True
# Step 155: LOST CONTROL!
# Step 100: OUT OF BOUNDS!
# Step 116: LOST CONTROL!
# Step 111: OUT OF BOUNDS!
# Step 133: OUT OF BOUNDS!
# Step 85: LOST CONTROL!
# Step 88: LOST CONTROL!
# Step 78: LOST CONTROL!
# Step 115: OUT OF BOUNDS!
# Step 83: LOST CONTROL!
# Step 154: LOST CONTROL!
# Step 66: OUT OF BOUNDS!
# Step 77: LOST CONTROL!
# Step 128: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 341.3 deg. Moving Platform: True
# Step 86: OUT OF BOUNDS!
# Step 56: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 76: OUT OF BOUNDS!
# Step 220: OUT OF BOUNDS!
# Step 71: LOST CONTROL!
# Step 94: LOST CONTROL!
# Step 110: OUT OF BOUNDS!
# Step 100: LOST CONTROL!
# Step 93: LOST CONTROL!
# Step 110: LOST CONTROL!
# Step 98: OUT OF BOUNDS!
# Step 48: OUT OF BOUNDS!
# Step 111: OUT OF BOUNDS!
# Step 134: LOST CONTROL!
# Step 57: LOST CONTROL!
# Step 75: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 235.6 deg. Moving Platform: True
# Step 157: LOST CONTROL!
# Step 74: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 333.4 deg. Moving Platform: True
# Step 158: OUT OF BOUNDS!
# Step 74: OUT OF BOUNDS!
# Step 134: LOST CONTROL!
# Step 116: OUT OF BOUNDS!
# Step 98: LOST CONTROL!
# Step 65: LOST CONTROL!
# Step 136: LOST CONTROL!
# Step 56: OUT OF BOUNDS!
# Step 129: LOST CONTROL!
# Step 103: LOST CONTROL!Step 120: OUT OF BOUNDS!
#
# Step 65: OUT OF BOUNDS!
# Step 90: LOST CONTROL!
# Step 78: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 32.3 deg. Moving Platform: True
# Step 138: LOST CONTROL!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 319.7 deg. Moving Platform: True
# Step 63: LOST CONTROL!
# Step 89: LOST CONTROL!
# Step 91: LOST CONTROL!
# Step 83: LOST CONTROL!
# Step 126: OUT OF BOUNDS!
# Step 92: LOST CONTROL!
# Step 102: LOST CONTROL!
# Step 184: OUT OF BOUNDS!
# Step 152: LOST CONTROL!
# Step 98: LOST CONTROL!
# Step 60: LOST CONTROL!
# Step 130: LOST CONTROL!
# Step 80: OUT OF BOUNDS!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 16.1 deg. Moving Platform: True
# Step 86: OUT OF BOUNDS!
# Step 112: LOST CONTROL!
# Step 81: LOST CONTROL!
# Step 115: OUT OF BOUNDS!
# Step 67: LOST CONTROL!
# Step 96: LOST CONTROL!
# Step 170: LOST CONTROL!
# Step 132: LOST CONTROL!
# Step 88: OUT OF BOUNDS!
# Step 95: LOST CONTROL!
# Step 105: OUT OF BOUNDS!
# Step 144: LOST CONTROL!
# Step 77: LOST CONTROL!
# Step 52: OUT OF BOUNDS!
# Step 70: LOST CONTROL!
# Step 111: LOST CONTROL!
#
# ...
# Step 535: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 16.5 deg. Moving Platform: True
# Step 568: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 679: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 159.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 410: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 0.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 530: OUT OF BOUNDS!
# Step 558: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 31.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 350.6 deg. Moving Platform: True
# Step 649: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 619: OUT OF BOUNDS!
# Step 579: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 26.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 237.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 715: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 270.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 330.9 deg. Moving Platform: True
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 287.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 222.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 229.0 deg. Moving Platform: True
# Step 500: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 332.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 585: OUT OF BOUNDS!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 151.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 556: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 629: OUT OF BOUNDS!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 228.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 547: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 327: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 679: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 710: OUT OF BOUNDS!
# Step 418: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 581: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 203.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 467: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 358.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 612: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 418: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 352.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 265.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 371: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 237.7 deg. Moving Platform: True
# Step 528: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 13.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 297.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 348.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 136.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 167.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 542: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 317.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 117.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 666: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 725: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 240.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 491: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 742: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 627: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 161.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 417: OUT OF BOUNDS!
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 740        |
# |    ep_rew_mean          | -14.4      |
# | time/                   |            |
# |    fps                  | 1259       |
# |    iterations           | 120        |
# |    time_elapsed         | 2341       |
# |    total_timesteps      | 2949120    |
# | train/                  |            |
# |    approx_kl            | 0.01225153 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.466     |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.3        |
# |    n_updates            | 1190       |
# |    policy_gradient_loss | 0.00219    |
# |    std                  | 0.307      |
# |    value_loss           | 0.735      |
# ----------------------------------------
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 328.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 355.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 472: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 509: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 277.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 115.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 46.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 143.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 51.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 494: OUT OF BOUNDS!
# Step 478: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 322.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 561 ---
# Wind Enabled: True, Wind Dir: 100.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 210.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 561: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 467: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 596: OUT OF BOUNDS!
# Step 490: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 597: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 571 ---
# Wind Enabled: True, Wind Dir: 337.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 689: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Training Finished (or interrupted) ---
# Saving final model to: models/ppo_ray_drone_1
# Environment closed.
#
# --- Training Script Complete ---
# To monitor training, run: tensorboard --logdir logs/drone_ppo_ray/

# %% [markdown]
# **Explanation and How to Use:**
#
# 1.  **Save:** Save this code as a Python file (e.g., `train_drone_agent.py`) in your project, likely at the root level or wherever you keep your training scripts.
# 2.  **Adjust Import:** **Crucially**, fix the import path for `Drone2dEnv` at the top of the script to match your project's directory structure. The provided `try...except` block attempts common scenarios.
# 3.  **Configure Training:**
#     *   `TOTAL_TIMESTEPS`: Set how long you want to train (1.8 million is a reasonable starting point, but might need more or less).
#     *   `LOG_DIR`: Choose where TensorBoard logs will be saved.
#     *   `MODEL_SAVE_PATH`: Choose where the final trained model `.zip` file will be saved.
#     *   `CHECKPOINT_FREQ`: How often to save intermediate models (useful if training crashes).
#     *   `N_ENVS`: Number of parallel environments. Start with `4` or match the number of CPU cores you have available. Using more environments generally speeds up training but uses more RAM.
# 4.  **Configure Environment:** Modify the `ENV_CONFIG` dictionary to set the desired parameters for the `Drone2dEnv` during training (wind, moving platform, start range, etc.). **Remember to keep `render_sim=False` for efficient training.**
# 5.  **Install Dependencies:** Make sure you have the necessary libraries installed in your environment:
#     ```bash
#     pip install stable-baselines3[extra] gym pygame pymunk numpy
#     pip install 'shimmy>=2.0
#     # Or if using gymnasium:
#     # pip install stable-baselines3[extra] gymnasium pygame pymunk numpy
#     ```
#     *(You might already have these from setting up the environment)*
# 6.  **Run Training:** Open your terminal, navigate to the directory where you saved the script, and run:
#     ```bash
#     python train_drone_agent.py
#     ```
# 7.  **Monitor with TensorBoard:** While training is running (or after it finishes), open *another* terminal, navigate to the same project directory (or one level above `LOG_DIR`), and run:
#     ```bash
#     tensorboard --logdir logs/drone_ppo/
#     ```
#     Then open the URL provided by TensorBoard (usually `http://localhost:6006/`) in your web browser to see graphs of the reward, loss functions, episode length, etc. This is essential for understanding if the agent is learning.
# 8.  **Tuning:** If the agent doesn't learn well, you may need to:
#     *   Adjust the environment parameters (e.g., make the task easier initially by disabling wind or the moving platform).
#     *   Tune the PPO hyperparameters within the `model = MODEL_ALGORITHM(...)` call (learning rate, rollout buffer size `n_steps`, etc.).
#     *   Modify the reward function in `drone_2d_env.py` if the current shaping isn't effective.
#     *   Train for longer (increase `TOTAL_TIMESTEPS`).

# %% [markdown]
# # Continuing/ resume training

# %% [markdown]
# ## Configurations  - Continue Training

# %%
# --- Training Configuration ---
# *** Paths ***
LOAD_MODEL_PATH = "models/ppo_ray_drone_1.zip" # <-- IMPORTANT: Path to the model saved previously
NEW_SAVE_PATH = "models/ppo_ray_drone_1_continued" # <-- Path to save the model after *this* training session
LOG_DIR = "logs/drone_ppo/" # <-- Directory for TensorBoard logs (can be same or new)

# *** Training Parameters ***
ADDITIONAL_TIMESTEPS = 4_000_000 # <-- How many *more* steps to train
MODEL_ALGORITHM = PPO         # <-- Must match the algorithm of the loaded model
POLICY_TYPE = "MlpPolicy"     # <-- Must match the policy type of the loaded model
CHECKPOINT_FREQ = 50000       # Save a checkpoint every N steps (during this session)
N_ENVS = 10                    # Number of parallel environments (match previous setup if possible)

# %% [markdown]
# **Test Load**

# %%
from stable_baselines3 import PPO

# Attempt to load the saved model
model_loaded = PPO.load(LOAD_MODEL_PATH)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# ## Continuing training ENV 1

# %% [markdown]
# **Key features:**
#
# *   Specifies the path to the model you want to load (`LOAD_MODEL_PATH`).
# *   Specifies a *new* path to save the model after continued training (`NEW_SAVE_PATH`).
# *   Specifies the number of *additional* timesteps to train for (`ADDITIONAL_TIMESTEPS`).
# *   Uses the same environment configuration (`ENV_CONFIG`) - **important for compatibility**.
# *   Sets `reset_num_timesteps=False` in `model.learn()` to ensure the training step count and logs continue correctly.
# *   Includes error handling if the specified model to load doesn't exist.

# %%
import os
import gym
from stable_baselines3 import PPO  # Or the algorithm you used (e.g., SAC, TD3)
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import CheckpointCallback

# --- Environment Import ---

from drone_2d_custom_gym_env.drone_2d_env_raycast import Drone2dEnvRaycastV2



# --- Setup ---
os.makedirs(os.path.dirname(NEW_SAVE_PATH), exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True) # Log dir might already exist

print("--- Starting Drone Training Continuation ---")
print(f"Attempting to load model from: {LOAD_MODEL_PATH}")
print(f"Training for additional {ADDITIONAL_TIMESTEPS} timesteps.")
print(f"Environment Config: {ENV_CONFIG}")

# --- Check if Model Exists ---
if not os.path.exists(LOAD_MODEL_PATH):
    print(f"\n!!! Error: Model file not found at {LOAD_MODEL_PATH} !!!")
    print("Cannot continue training without a model to load.")
    exit()

# --- Create Vectorized Environment ---
# Needs to be created *before* loading the model
try:
    env = make_vec_env(
        Drone2dEnvRaycastV2,
        n_envs=N_ENVS,
        seed=0, # Seed can be different, but structure should be same
        vec_env_cls=SubprocVecEnv,
        env_kwargs=ENV_CONFIG
    )
except Exception as e:
    print(f"\n!!! Error creating environment: {e} !!!")
    exit()

# --- Load Model ---
try:
    print(f"\nLoading model...")
    # Pass the environment and tensorboard log directory to load
    # SB3 automatically detects the algorithm and policy type from the zip file
    model = MODEL_ALGORITHM.load(
        LOAD_MODEL_PATH,
        env=env, # Link the loaded model to the (new) environment instances
        tensorboard_log=LOG_DIR # Tell SB3 where to continue logging
    )
    print(f"Model loaded successfully. Current Timesteps: {model.num_timesteps}")
except Exception as e:
    print(f"\n!!! Error loading model from {LOAD_MODEL_PATH}: {e} !!!")
    print("Check if the file exists, is a valid SB3 model, and matches the environment structure.")
    env.close()
    exit()

# --- Setup Checkpoint Callback ---
checkpoint_callback = CheckpointCallback(
    save_freq=max(CHECKPOINT_FREQ // N_ENVS, 1),
    save_path=LOG_DIR, # Save checkpoints in the log directory
    name_prefix=f"{os.path.basename(NEW_SAVE_PATH)}_ckpt" # Prefix based on new save name
)

# --- Continue Training ---
print("\n--- Continuing Training ---")
start_timesteps = model.num_timesteps # Get current steps from loaded model
target_timesteps = start_timesteps + ADDITIONAL_TIMESTEPS
print(f"Training from {start_timesteps} to {target_timesteps} total steps.")

try:
    model.learn(
        total_timesteps=ADDITIONAL_TIMESTEPS, # Train for the *additional* steps
        log_interval=10,
        tb_log_name=f"{MODEL_ALGORITHM.__name__}_Drone", # Use same or new log name
        reset_num_timesteps=False, # <-- IMPORTANT: Do NOT reset timestep counter
        callback=checkpoint_callback
        )
except Exception as e:
    print(f"\n!!! Error during continued training: {e} !!!")
    print("Attempting to save model before exiting...")
    model.save(f"{NEW_SAVE_PATH}_error")
finally:
    # --- Save the Final Model ---
    print("\n--- Training Finished (or interrupted) ---")
    print(f"Saving final model to: {NEW_SAVE_PATH}.zip") # SB3 adds .zip automatically
    model.save(NEW_SAVE_PATH) # Use the NEW save path

    # --- Clean up ---
    env.close()
    print("Environment closed.")

print("\n--- Training Continuation Script Complete ---")
print(f"To monitor training, run: tensorboard --logdir {LOG_DIR}")
# Out:
# --- Starting Drone Training Continuation ---
# Attempting to load model from: models/ppo_ray_drone_1.zip
# Training for additional 4000000 timesteps.
# Environment Config: {'render_sim': False, 'max_steps': 750, 'render_path': False, 'render_shade': False, 'shade_distance_m': 2.0, 'moving_platform': True, 'platform_speed': 2.0, 'initial_pos_random_range_m': 8.0, 'max_allowed_tilt_angle_rad': 2, 'enable_wind': True, 'reward_landing': 500, 'reward_un_landing': 50}
# RaycastV2 Observation Space Shape: (17,)RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 92.3 deg. Moving Platform: True
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 13.0 deg. Moving Platform: True
#
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 1.9 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 54.6 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 122.9 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 339.9 deg. Moving Platform: True
# RaycastV2 Observation Space Shape: (17,)RaycastV2 Observation Space Shape: (17,)
#
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 228.3 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 4.1 deg. Moving Platform: TrueRaycastV2 Observation Space Shape: (17,)
#
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 267.4 deg. Moving Platform: True
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 115.0 deg. Moving Platform: True
#
# Loading model...
# Model loaded successfully. Current Timesteps: 3022848
#
# --- Continuing Training ---
# Training from 3022848 to 7022848 total steps.
# Logging to logs/drone_ppo/PPO_Drone_0
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/sebas_dev_linux/miniconda3/envs/drone_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!Step 750: MAX STEPS REACHED!
#
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 544: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!Step 750: MAX STEPS REACHED!
#
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!Step 750: MAX STEPS REACHED!
#
# Step 750: MAX STEPS REACHED!
# Step 511: OUT OF BOUNDS!
# Step 451: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 12.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 278.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 32.8 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 170.3 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 73.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 244.4 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 137.3 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 210.7 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 122.1 deg. Moving Platform: True
#
# --- Resetting Episode 11 ---
# Wind Enabled: True, Wind Dir: 65.3 deg. Moving Platform: True
# Step 200: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 460: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!Step 750: MAX STEPS REACHED!
#
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 578: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 700: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 574: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 429: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 584: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 686: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 7.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 307.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 212.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 155.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 348.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 148.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 248.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 205.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 51.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 21 ---
# Wind Enabled: True, Wind Dir: 204.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 716: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 630: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 574: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | -12.3       |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 10          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 3227648     |
# | train/                  |             |
# |    approx_kl            | 0.014139143 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.189       |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.00181     |
# |    std                  | 0.277       |
# |    value_loss           | 0.659       |
# -----------------------------------------
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 222.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 353.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 213.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 353.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 335.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 272.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 174.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 303.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 89.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 31 ---
# Wind Enabled: True, Wind Dir: 332.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 518: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 601: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 220: OUT OF BOUNDS!
# Step 567: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 397: OUT OF BOUNDS!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 336.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 35.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 207.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 53.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 77.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 96.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 214.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 14.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 350.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 41 ---
# Wind Enabled: True, Wind Dir: 273.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 536: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 534: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 469: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 554: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 322.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 11.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 143.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 332.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 95.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 251.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 207.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 12.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 138.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 51 ---
# Wind Enabled: True, Wind Dir: 42.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 256: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 601: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 451: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 232: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 528: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 527: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 629: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 574: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 1017        |
# |    iterations           | 20          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 3432448     |
# | train/                  |             |
# |    approx_kl            | 0.012000581 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0819      |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.0022      |
# |    std                  | 0.261       |
# |    value_loss           | 0.621       |
# -----------------------------------------
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 300.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 227.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 51.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 266.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 228.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 208.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 123.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 216.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 262.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 61 ---
# Wind Enabled: True, Wind Dir: 6.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 196.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 64.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 264.9 deg. Moving Platform: True
# Step 687: LOST CONTROL!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 227.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 107.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 120.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 277.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 152.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 306.3 deg. Moving Platform: True
# Step 669: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 71 ---
# Wind Enabled: True, Wind Dir: 187.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 607: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 716: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 360: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 541: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 530: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 347.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 152.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 103.4 deg. Moving Platform: True
# Step 529: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 293.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 356.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 309.2 deg. Moving Platform: True
# Step 345: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 345.5 deg. Moving Platform: True
# Step 744: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 5.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 726: OUT OF BOUNDS!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 251.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 81 ---
# Wind Enabled: True, Wind Dir: 227.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 30          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 3637248     |
# | train/                  |             |
# |    approx_kl            | 0.013681149 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0507     |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.8         |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | 0.00394     |
# |    std                  | 0.249       |
# |    value_loss           | 6.32        |
# -----------------------------------------
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 677: OUT OF BOUNDS!
# Step 647: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 508: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 236.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 327.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 283.2 deg. Moving Platform: True
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 15.0 deg. Moving Platform: True
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 56.7 deg. Moving Platform: True
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 157.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 100.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 54.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 137.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 91 ---
# Wind Enabled: True, Wind Dir: 140.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 560: LOST CONTROL!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 206.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 173.0 deg. Moving Platform: True
# Step 671: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 154.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 223.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 34.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 232.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 349.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 196.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 106.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 101 ---
# Wind Enabled: True, Wind Dir: 126.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 607: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 560: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 729: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 532: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 556: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# Wind Enabled: True, Wind Dir: 265.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# Wind Enabled: True, Wind Dir: 211.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# Wind Enabled: True, Wind Dir: 9.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# Wind Enabled: True, Wind Dir: 58.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# Wind Enabled: True, Wind Dir: 18.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 111 ---
# ...
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 741: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 536: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 695: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 511 ---
# Wind Enabled: True, Wind Dir: 224.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 702: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 625: OUT OF BOUNDS!
# Step 685: OUT OF BOUNDS!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 282.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 86.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 263.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 268.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 461: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 240.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 240.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 542: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 169.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 738: OUT OF BOUNDS!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 223.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 557: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 340.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 447: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 635: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 664: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 609: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 578: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 521 ---
# Wind Enabled: True, Wind Dir: 142.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 700: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 717: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 105.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 268: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 646: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 197.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 52.6 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 164.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 287.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 48.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 258: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 92.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 630: OUT OF BOUNDS!
# Step 513: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 158.5 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 525: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 190.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 593: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 606: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 529: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 549: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 531 ---
# Wind Enabled: True, Wind Dir: 147.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 597: OUT OF BOUNDS!
# Step 405: OUT OF BOUNDS!
# Step 511: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 59.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 719         |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 904         |
# |    iterations           | 190         |
# |    time_elapsed         | 4300        |
# |    total_timesteps      | 6914048     |
# | train/                  |             |
# |    approx_kl            | 0.015566172 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.27        |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 3120        |
# |    policy_gradient_loss | 0.00336     |
# |    std                  | 0.128       |
# |    value_loss           | 1.47        |
# -----------------------------------------
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 434: OUT OF BOUNDS!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 119.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 636: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 327.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 270.7 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 44.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 244.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 580: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 145.4 deg. Moving Platform: True
# Step 727: OUT OF BOUNDS!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 171.3 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 613: LOST CONTROL!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 682: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 260.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 543: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 569: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 541 ---
# Wind Enabled: True, Wind Dir: 332.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 687: LOST CONTROL!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 285.1 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 277.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 231.0 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 74.2 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 293.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 189.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 629: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 308.8 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 35.9 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 661: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Resetting Episode 551 ---
# Wind Enabled: True, Wind Dir: 240.4 deg. Moving Platform: True
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 207: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 720: OUT OF BOUNDS!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
# Step 750: MAX STEPS REACHED!
#
# --- Training Finished (or interrupted) ---
# Saving final model to: models/ppo_ray_drone_1_continued.zip
# Environment closed.
#
# --- Training Continuation Script Complete ---
# To monitor training, run: tensorboard --logdir logs/drone_ppo/

# %% [markdown]
# **Explanation and How to Use:**
#
# 1.  **Save:** Save this code as `continue_training.py` (or similar) in your project.
# 2.  **Configure Paths:**
#     *   Set `LOAD_MODEL_PATH` to the exact path of the `.zip` file generated by your previous training run (e.g., `models/ppo_drone_final.zip`).
#     *   Set `NEW_SAVE_PATH` to where you want the model saved *after this continuation*. It's generally good practice to give it a distinct name initially (e.g., `models/ppo_drone_final_continued`).
#     *   Set `LOG_DIR` (usually the same as before, so TensorBoard shows one continuous graph).
# 3.  **Configure Training:**
#     *   Set `ADDITIONAL_TIMESTEPS` to the number of *extra* steps you want to train for.
#     *   Ensure `MODEL_ALGORITHM` matches the algorithm used to create the loaded model (the script will load it automatically, but it's good practice).
# 4.  **Configure Environment (`ENV_CONFIG`):** Make sure this dictionary matches the settings used during the *original* training run, or at least is compatible (same observation/action space dimensions).
# 5.  **Run:** Execute the script from your terminal:
#     ```bash
#     python continue_training.py
#     ```
# 6.  **Monitor:** Use TensorBoard as before, pointing it to the `LOG_DIR`. You should see the training metrics continue from where the previous run left off.
#
# This script provides a robust way to resume training your drone landing agent.

# %% [markdown]
# # Evaluation Agent

# %% [markdown]
# ## Evaluation Configuration

# %%
# --- Evaluation Configuration ---
# *** Paths ***
MODEL_PATH = "models/ppo_ray_drone_1.zip" # <-- IMPORTANT: Path to the trained model to evaluate
# MODEL_PATH = "logs/drone_ppo/drone_ppo_ckpt_100000_steps.zip" # Example for loading a checkpoint

# *** Evaluation Parameters ***
NUM_EVAL_EPISODES = 1000        # How many episodes to run for evaluation
RENDER_SIM = True             # Set to True to watch the agent perform
#RENDER_SIM = False             # Set to True to watch the agent perform
#RENDER_DELAY_S = 0.03         # Delay between frames when rendering (seconds)
RENDER_DELAY_S = 0.0         # Delay between frames when rendering (seconds) 0.00 - 0.03


# *** Environment Configuration for Evaluation ***
# Use settings representative of how you expect the agent to perform,
# or the specific conditions you want to test.
# Often similar or identical to training config, but render_sim=True here.
ENV_CONFIG_EVAL = {

    "render_sim": RENDER_SIM,         # Use the RENDER_SIM flag here
    "max_steps": 600,                # Allow more steps for evaluation if needed
    "render_path": True,              # Enable path/shade rendering for visualization
    "render_shade": True,
    "shade_distance_m": 2.0,
             
    # No if we are going to evaluate same conditions
    
    "moving_platform": MOVING_PLATFORM,        #  Train with moving platform
    "platform_speed": PLATFORM_SPEED,           #  Platform speed if moving
    "initial_pos_random_range_m": INITIAL_POST_RAMDOM_RANGE_M,#  Random start range
    "max_allowed_tilt_angle_rad": MAX_ALLOWED_TILT_ANGLE_RAD, #  Allow slightly more tilt (approx 90 deg)
    "enable_wind": ENABLE_WIND,             #  Train with wind enabled
    'reward_landing': REWARD_LANDING,           #  reward for landing more high reward increase interest   
    'reward_un_landing': REWARD_UN_LANDING          #  reward for unstable landing more high reward increase interest    
    # Note: wind_speed is fixed at 5.0 inside the env for now
}

# %%
import os
import gym
import numpy as np
import time
import pygame # Import pygame directly for flip
from stable_baselines3 import PPO # Or the algorithm you used (e.g., SAC, TD3)
# REMOVED: from stable_baselines3.common.vec_env import DummyVecEnv

# --- Environment Import ---
from drone_2d_custom_gym_env.drone_2d_env_raycast import Drone2dEnvRaycastV2





# --- Helper Function --- MODIFIED ---
def evaluate_agent(model, env, num_episodes=10, render=False, delay=0.0):
    """
    Evaluates a Stable Baselines3 agent on a single environment instance.

    :param model: The agent to evaluate.
    :param env: The single environment instance.
    :param num_episodes: Number of episodes to run.
    :param render: Whether to render the environment.
    :param delay: Delay between frames if rendering.
    :return: Dictionary containing evaluation statistics including outcome counts.
    """
    episode_rewards = []
    episode_lengths = []
    # --- Outcome Counters ---
    episode_outcomes = {
        "Landed Safely": 0,
        "Crashed": 0,
        "Lost Control": 0,
        "Out of Bounds": 0,
        "Battery Empty": 0,
        "Timeout": 0,
        "Error": 0, # For unexpected terminations
    }
    # --- End Counters ---

    # Get clock and fps if rendering and available
    the_clock = None; render_fps = 50
    if render and hasattr(env, 'clock') and env.clock: the_clock = env.clock
    if render and hasattr(env, 'metadata') and 'render_fps' in env.metadata: render_fps = env.metadata['render_fps']

    for episode in range(num_episodes):
        obs = env.reset()
        done = False
        current_episode_reward = 0
        current_episode_length = 0
        final_info_dict = {} # Store final info from step before termination

        print(f"  Starting Eval Episode {episode + 1}/{num_episodes}...")

        while not done:
            if render:
                try:
                    env.render(); pygame.display.flip()
                    if the_clock: the_clock.tick(render_fps)
                    if delay > 0: time.sleep(delay)
                except Exception as e: print(f"Error rendering/updating display: {e}"); render = False

            action, _states = model.predict(obs, deterministic=True)

            try:
                obs, reward, done, info = env.step(action)
                current_episode_reward += reward
                current_episode_length += 1
                final_info_dict = info # Store latest info

            except Exception as e:
                 print(f"Error during env.step(): {e}. Terminating episode.")
                 done = True
                 final_info_dict['error'] = f"Exception during step: {e}" # Mark error in dict

        # --- Episode Finished ---
        episode_rewards.append(current_episode_reward)
        episode_lengths.append(current_episode_length)

        # --- Increment Outcome Counter (Prioritized) ---
        outcome_recorded = False
        if final_info_dict.get('error'): # Check for explicit error first
            episode_outcomes["Error"] += 1
            print(f"  Episode {episode + 1}: FAILED (Error during step)")
            outcome_recorded = True
        elif final_info_dict.get('landed_safely', False):
            episode_outcomes["Landed Safely"] += 1
            print(f"  Episode {episode + 1}: SUCCESS (Landed Safely)")
            outcome_recorded = True
        elif final_info_dict.get('crashed', False):
            episode_outcomes["Crashed"] += 1
            print(f"  Episode {episode + 1}: FAILED (Crashed)")
            outcome_recorded = True
        elif final_info_dict.get('lost_control', False):
            episode_outcomes["Lost Control"] += 1
            print(f"  Episode {episode + 1}: FAILED (Lost Control)")
            outcome_recorded = True
        elif final_info_dict.get('out_of_bounds', False):
            episode_outcomes["Out of Bounds"] += 1
            print(f"  Episode {episode + 1}: FAILED (Out of Bounds)")
            outcome_recorded = True
        elif final_info_dict.get('Battery_empty', False):
            episode_outcomes["Battery Empty"] += 1
            print(f"  Episode {episode + 1}: FAILED (Battery Empty)")
        # Check timeout ONLY if no other condition was met
        elif current_episode_length >= env.max_steps:
            episode_outcomes["Timeout"] += 1
            print(f"  Episode {episode + 1}: FAILED (Timeout)")
            outcome_recorded = True

        # Fallback if done=True but no specific flag was set (should be rare)
        if not outcome_recorded and done:
             episode_outcomes["Error"] += 1 # Count as error
             print(f"  Episode {episode + 1}: FAILED (Unknown - 'done' but no specific flag)")
        # --- End Outcome Counter ---

        print(f"  Episode {episode + 1}: Length={current_episode_length}, Reward={current_episode_reward:.2f}")

    # --- Calculate Statistics ---
    mean_reward = np.mean(episode_rewards) if episode_rewards else 0; std_reward = np.std(episode_rewards) if episode_rewards else 0
    mean_length = np.mean(episode_lengths) if episode_lengths else 0
    # Calculate success rate based on counter
    success_rate = episode_outcomes["Landed Safely"] / num_episodes if num_episodes > 0 else 0

    stats = {
        "mean_reward": mean_reward, "std_reward": std_reward,
        "mean_length": mean_length, "success_rate": success_rate,
        "outcomes": episode_outcomes, # Include the outcome counts
        "total_episodes": num_episodes
    }
    return stats


if __name__ == "__main__":
    print("--- Starting Drone Agent Evaluation ---")
    print(f"Loading model from: {MODEL_PATH}")
    print(f"Evaluating for {NUM_EVAL_EPISODES} episodes.")
    print(f"Evaluation Environment Config: {ENV_CONFIG_EVAL}")

    if not os.path.exists(MODEL_PATH):
        print(f"\n!!! Error: Model file not found at {MODEL_PATH} !!!"); exit()

    # --- Create SINGLE Evaluation Environment ---
    try:
        eval_env = Drone2dEnvRaycastV2(**ENV_CONFIG_EVAL)
        print("Single evaluation environment created.")
    except Exception as e: print(f"\n!!! Error creating evaluation environment: {e} !!!"); exit()

    # --- Load Model ---
    try:
        loaded_model = PPO.load(MODEL_PATH, env=eval_env) # Pass single env
        print("\nModel loaded successfully.")
    except Exception as e: print(f"\n!!! Error loading model: {e} !!!"); eval_env.close(); exit()

    # --- Run Evaluation ---
    print("\n--- Running Evaluation Loop ---")
    eval_stats = evaluate_agent(
        model=loaded_model, env=eval_env, num_episodes=NUM_EVAL_EPISODES,
        render=RENDER_SIM, delay=RENDER_DELAY_S
    )

    # --- Print Summary --- MODIFIED ---
    print("\n\n--- Evaluation Summary ---")
    print(f"Evaluated for {eval_stats['total_episodes']} episodes.")
    print(f"Mean Reward: {eval_stats['mean_reward']:.2f} +/- {eval_stats['std_reward']:.2f}")
    print(f"Mean Episode Length: {eval_stats['mean_length']:.1f}")
    print(f"Success Rate (Landed Safely): {eval_stats['success_rate']:.2%}")
    print("\nEpisode Outcome Counts:")
    for outcome, count in eval_stats['outcomes'].items():
        # Print even if count is 0 for completeness
        print(f"  - {outcome}: {count}")
    print("--------------------------")
    # --- End Modification ---

    # --- Cleanup ---
    eval_env.close()
    print("Evaluation environment closed.")
    print("--- Evaluation Script Complete ---")
# Out:
# --- Starting Drone Agent Evaluation ---
# Loading model from: models/ppo_ray_drone_1.zip
# Evaluating for 1000 episodes.
# Evaluation Environment Config: {'render_sim': True, 'max_steps': 600, 'render_path': True, 'render_shade': True, 'shade_distance_m': 2.0, 'moving_platform': True, 'platform_speed': 2.0, 'initial_pos_random_range_m': 8.0, 'max_allowed_tilt_angle_rad': 2, 'enable_wind': True, 'reward_landing': 500, 'reward_un_landing': 50}
# RaycastV2 Observation Space Shape: (17,)
#
# --- Resetting Episode 1 ---
# Wind Enabled: True, Wind Dir: 160.1 deg. Moving Platform: True
# Single evaluation environment created.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Model loaded successfully.
#
# --- Running Evaluation Loop ---
#   Starting Eval Episode 1/1000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 158
#     156 # --- Run Evaluation ---
#     157 print("\n--- Running Evaluation Loop ---")
# --> 158 eval_stats = evaluate_agent(
#     159     model=loaded_model, env=eval_env, num_episodes=NUM_EVAL_EPISODES,
#     160     render=RENDER_SIM, delay=RENDER_DELAY_S
#     161 )
#     163 # --- Print Summary --- MODIFIED ---
#     164 print("\n\n--- Evaluation Summary ---")
#
# Cell In[10], line 59, in evaluate_agent(model, env, num_episodes, render, delay)
#      57 if render:
#      58     try:
# ---> 59         env.render(); pygame.display.flip()
#      60         if the_clock: the_clock.tick(render_fps)
#      61         if delay > 0: time.sleep(delay)
#
# File ~/miniconda3/envs/drone_env/lib/python3.10/site-packages/drone_2d_custom_gym_env/drone_2d_env_raycast.py:920, in Drone2dEnvRaycastV2.render(self, mode)
#     917     stats_text2=f"LoC:{self.ep_count_lost_control}|OoB:{self.ep_count_out_of_bounds}|Bat:{self.ep_count_battery_empty}|Timeout:{self.ep_count_timeout}"; stats_surf2=self.font.render(stats_text2,True,text_color); self.screen.blit(stats_surf2,(10,current_y));
#     919 pygame.display.flip();
# --> 920 if self.clock: self.clock.tick(self.metadata['render_fps'])
#
# KeyboardInterrupt:
